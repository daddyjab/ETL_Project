# %%
import pandas as pd
import pymongo

# Initialize PyMongo to work with MongoDBs
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# Define database and collection
db = client.etl_db

# Convert the items in MongoDB collection
# to a flat format for import to DataFrame
iwp_info = db.iwp.find()

new_i_list = []

for i in iwp_info:
    # Create a new list of dicts with flat entries
    #print(i['incident_title'])
    new_dict = {
         'incident_title': i['incident_title'],
         'incident_date': i['incident_date'],
         'incident_url': i['incident_url'],
         'incident_report_type': i['incident_report_type'],
         'incident_symptoms': ", ".join(i['incident_symptoms']),
         'incident_misc': i['incident_misc'],
          'incident_address': i['incident_address_info']['incident_address'],
          'incident_address_standard': i['incident_address_info']['incident_address_standard'],
          'incident_address_street': i['incident_address_info']['incident_address_street'],
          'incident_address_street2': i['incident_address_info']['incident_address_street2'],
          'incident_address_street3': i['incident_address_info']['incident_address_street3'],
          'incident_address_city': i['incident_address_info']['incident_address_city'],
          'incident_address_state': i['incident_address_info']['incident_address_state'],
          'incident_address_zipcode': i['incident_address_info']['incident_address_zipcode'],
          'incident_address_country': i['incident_address_info']['incident_address_country'],
         'incident_description': i['incident_description']
         }
    
    new_i_list.append(new_dict)


# Try to import the dictionary into pandas
iwp_df = pd.DataFrame(new_i_list)
iwp_df.head()
# Out:
#                                     incident_address incident_address_city  \
# 0  1438 West Grand Parkway North, Katy, 77449 Tex...                  Katy
# 1  705 South James Campbell Boulevard, Columbia, ...              Columbia
# 2  8275 Compton Avenue, Los Angeles, 90001 Califo...           Los Angeles
# 3  210 North Aviation Boulevard, Manhattan Beach,...       Manhattan Beach
# 4  45510 Michigan Avenue, Canton, 48188 Michigan,...                Canton
#
#   incident_address_country                          incident_address_standard  \
# 0            United States  1438 West Grand Parkway North, Katy, Texas 774...
# 1            United States  705 South James Campbell Boulevard, Columbia, ...
# 2            United States  8275 Compton Avenue, Los Angeles, California 9...
# 3            United States  210 North Aviation Boulevard, Manhattan Beach,...
# 4            United States  45510 Michigan Avenue, Canton, Michigan 48188,...
#
#   incident_address_state             incident_address_street  \
# 0                  Texas       1438 West Grand Parkway North
# 1              Tennessee  705 South James Campbell Boulevard
# 2             California                 8275 Compton Avenue
# 3             California        210 North Aviation Boulevard
# 4               Michigan               45510 Michigan Avenue
#
#   incident_address_street2 incident_address_street3 incident_address_zipcode  \
# 0                                                                      77449
# 1                                                                      38401
# 2                                                                      90001
# 3                                                                      90266
# 4                                                                      48188
#
#        incident_date                               incident_description  \
# 0  Jan 1 2019 9:38pm  I ate the breakfast burrito and after a few ho...
# 1  Jan 1 2019 9:30pm  My fiancé and I both got sick after eating go ...
# 2  Jan 1 2019 9:28pm  Date Closed: 12/28/2018\nReason for closure: N...
# 3  Jan 1 2019 9:09pm  Date Closed: 12/28/2018\nReason for closure: N...
# 4  Jan 1 2019 8:57pm  Drank a McD's strawberry milkshake, symptoms s...
#
#   incident_misc                        incident_report_type  \
# 0                                            Food Poisoning
# 1                                            Food Poisoning
# 2                Temporary Closure - related to food safety
# 3                Temporary Closure - related to food safety
# 4                                            Food Poisoning
#
#             incident_symptoms  \
# 0                    Diarrhea
# 1  Diarrhea, Nausea, Vomiting
# 2
# 3
# 4     Fever, Nausea, Vomiting
#
#                                       incident_title  \
# 0  Sonic Drive-In, West Grand Parkway North, Katy...
# 1  Applebee's Grill + Bar, South James Campbell B...
# 2  LOPEZ STORE, 8275 Compton Avenue, Los Angeles,...
# 3  BOBALOCA MB / MADAME TOMATE, North Aviation Bo...
# 4    McDonald's, Michigan Ave, Canton, Michigan, USA
#
#                                         incident_url
# 0  https://iwaspoisoned.com/incident/sonic-drive-...
# 1  https://iwaspoisoned.com/incident/applebees-gr...
# 2  https://iwaspoisoned.com/incident/lopez-store-...
# 3  https://iwaspoisoned.com/incident/bobaloca-mb-...
# 4  https://iwaspoisoned.com/incident/mcdonalds-mi...
